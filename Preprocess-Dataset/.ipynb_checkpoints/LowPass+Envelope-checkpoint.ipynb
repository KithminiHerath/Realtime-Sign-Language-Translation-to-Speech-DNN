# %%
import pandas as pd
import numpy as np
import math
import os
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.decomposition import PCA                 # for dimensionality reduction using PCA
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix
import matplotlib.pyplot as plt 
import seaborn as sns            # visualization tool
import matplotlib.cm as cm       # for colour mapping to use for the pca plots
from scipy.signal import hilbert, chirp
from scipy import signal
from scipy.fftpack import fft

# %%
basepath = '/home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/'
outpath = '/home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/CLEANED/'
folders = os.listdir(basepath)

# %%
def listdir(x):
    return os.listdir(basepath+x)
def readcsv(x,y):
    file = basepath+x+'/'+y
    /print y
    return pd.read_csv(file)

def get_files(x,y):
    file = basepath+x+'/'+y
    return file
def create_folder(folder):
    directory=outpath+folder+'/'
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
for folder in folders:
    if '' in folder:
        files =  listdir(folder)
        
        
        for file in files:
            if 'csv' in file:
                data = get_files(folder,file)
                create_folder(folder)

                clean(data,file,folder)
                #print(data.head)
# Out:
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407313/orientation-1569407313.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407313/orientationEuler-1569407313.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407313/accelerometer-1569407313.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407313/gyro-1569407313.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407313/emg-1569407313.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407423/accelerometer-1569407423.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407423/orientationEuler-1569407423.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407423/gyro-1569407423.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407423/emg-1569407423.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407423/orientation-1569407423.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406226/orientationEuler-1569406226.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406226/emg-1569406226.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406226/accelerometer-1569406226.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406226/gyro-1569406226.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406226/orientation-1569406226.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406560/orientationEuler-1569406560.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406560/emg-1569406560.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406560/orientation-1569406560.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406560/gyro-1569406560.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406560/accelerometer-1569406560.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406602/orientationEuler-1569406602.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406602/gyro-1569406602.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406602/emg-1569406602.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406602/accelerometer-1569406602.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406602/orientation-1569406602.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406100/accelerometer-1569406100.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406100/emg-1569406100.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406100/gyro-1569406100.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406100/orientation-1569406100.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406100/orientationEuler-1569406100.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406286/orientationEuler-1569406286.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406286/orientation-1569406286.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406286/accelerometer-1569406286.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406286/gyro-1569406286.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YES-1569406286/emg-1569406286.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406402/gyro-1569406402.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406402/orientation-1569406402.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406402/emg-1569406402.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406402/orientationEuler-1569406402.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406402/accelerometer-1569406402.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407394/emg-1569407394.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407394/orientationEuler-1569407394.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407394/gyro-1569407394.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407394/accelerometer-1569407394.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407394/orientation-1569407394.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406524/orientationEuler-1569406524.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406524/accelerometer-1569406524.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406524/gyro-1569406524.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406524/orientation-1569406524.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/YELLOW-1569406524/emg-1569406524.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408282/accelerometer-1569408282.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408282/emg-1569408282.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408282/orientation-1569408282.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408282/orientationEuler-1569408282.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408282/gyro-1569408282.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407584/orientationEuler-1569407584.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407584/emg-1569407584.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407584/orientation-1569407584.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407584/accelerometer-1569407584.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/THANKYOU-1569407584/gyro-1569407584.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408080/gyro-1569408080.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408080/emg-1569408080.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408080/accelerometer-1569408080.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408080/orientationEuler-1569408080.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408080/orientation-1569408080.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406437/orientation-1569406437.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406437/emg-1569406437.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406437/gyro-1569406437.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406437/accelerometer-1569406437.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406437/orientationEuler-1569406437.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408148/accelerometer-1569408148.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408148/orientationEuler-1569408148.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408148/emg-1569408148.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408148/gyro-1569408148.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408148/orientation-1569408148.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408050/emg-1569408050.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408050/orientationEuler-1569408050.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408050/orientation-1569408050.csv
# x
# y
# z
# w
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408050/accelerometer-1569408050.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/WATER-1569408050/gyro-1569408050.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406366/accelerometer-1569406366.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406366/gyro-1569406366.csv
# x
# y
# z
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406366/orientationEuler-1569406366.csv
# roll
# pitch
# yaw
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406366/emg-1569406366.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
# /home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/DATASET/NO-1569406366/orientation-1569406366.csv
# x
# y
# z
# w

# %%
def clean(filename,name,folder):
    main_signal=pd.read_csv(filename)
    print(filename)
    
    t= main_signal['timestamp']
    N=main_signal.shape[0]
    temp = np.array([])
    temp = np.hstack((temp, np.array(t)))
    cols = list(main_signal.columns)

    for column in cols[1:]: #miss the timestamp column
        print(column)
        signal_ =np.abs(main_signal[column])

        b, a = signal.butter(1,0.02, 'low', analog = False) 
        output = signal.filtfilt(b, a, signal_)

        analytic_signal = hilbert(output)
        amplitude_envelope = np.abs(analytic_signal)
        
        temp = np.vstack((temp, amplitude_envelope))

        fourier = np.fft.fft(output)

        s=0
        e=N
        
        
        plt.figure(figsize=(20,10))
        plt.plot(t[s:e], signal_[s:e], label='signal')
        plt.plot(t[s:e], output[s:e], label='signal')

        plt.plot(t[s:e], amplitude_envelope[s:e], label='envelope',color='black')
        plt.show()
        plt.plot(t[s:e], output[s:e], label='envelope',color='red')
        
        
        plt.plot(t[s:e], amplitude_envelope[s:e], label='envelope',color='black')
        plt.show()
        
        xf =np.fft.fftfreq(N)  

        #plt.plot((xf*200)[10:N//2], (fourier.real**2 + fourier.imag**2)[10:N//2])
        
    result = pd.DataFrame(temp.transpose(),columns = cols)
    result.to_csv(r'/home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/Preprocess/CLEANED/'+folder+'/'+name,index = False)

# %%
clean('/home/amaya/emp/DATASET/NO-1569406366/emg-1569406366.csv','emg-1569406366.csv','NO-1569406366');
# Out:
# /home/amaya/emp/DATASET/NO-1569406366/emg-1569406366.csv
# emg1
# emg2
# emg3
# emg4
# emg5
# emg6
# emg7
# emg8
