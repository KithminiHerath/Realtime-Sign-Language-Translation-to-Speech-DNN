# %%
import pandas as pd
import numpy as np
import math
import os
from sklearn import preprocessing

# %%
from sklearn.decomposition import PCA                 # for dimensionality reduction using PCA
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt 
import seaborn as sns            # visualization tool
import matplotlib.cm as cm       # for colour mapping to use for the pca plots

# %%
path = '/home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/NEW_PROCESS/recorded_data/'

# %%
data_no = pd.read_csv('/home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/NEW_PROCESS/emg-1569406437_1.csv').loc[:,'Emg1':]
data_water = pd.read_csv('/home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/NEW_PROCESS/emg-1569408148_1.csv').loc[:,'Emg1':]
data_yes = pd.read_csv('/home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/NEW_PROCESS/emg-1569406286_1.csv').loc[:,'Emg1':]

# %%
data_no2 = pd.read_csv('/home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/NEW_PROCESS/emg-1569406366_1.csv').loc[:,'Emg1':]
data_water2 = pd.read_csv('/home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/NEW_PROCESS/emg-1569408080_1.csv').loc[:,'Emg1':]
data_yes2 = pd.read_csv('/home/amaya/emp/Realtime-Sign-Language-Translation-to-Speech-DNN/NEW_PROCESS/emg-1569406226_1.csv').loc[:,'Emg1':]

# %%
print('Correlation of EMG sensors for "NO" gesture')
plt.figure(figsize = (16,10))
plt.subplot(1,2,1)
sns.heatmap(data_no.corr(),annot=True).set_ylim(8,0)
plt.title('emg-1569406437_1')
plt.subplot(1,2,2)
sns.heatmap(data_no2.corr(),annot=True).set_ylim(8,0)
plt.title('emg-1569406366_1')
# Out:
# Correlation of EMG sensors for "NO" gesture
# Text(0.5, 1, 'emg-1569406366_1')

# %%
print('Correlation of EMG sensors for "WATER" gesture')
plt.figure(figsize = (16,10))
plt.subplot(1,2,1)
sns.heatmap(data_water.corr(),annot=True).set_ylim(8,0)
plt.title('emg-1569408148_1')
plt.subplot(1,2,2)
sns.heatmap(data_water2.corr(),annot=True).set_ylim(8,0)
plt.title('emg-1569408080_1')
# Out:
# Correlation of EMG sensors for "WATER" gesture
# Text(0.5, 1, 'emg-1569408080_1')

# %%
print('Correlation of EMG sensors for "YES" gesture')
plt.figure(figsize = (16,10))
plt.subplot(1,2,1)
sns.heatmap(data_yes.corr(),annot=True).set_ylim(8,0)
plt.title('emg-1569406286_1')
plt.subplot(1,2,2)
sns.heatmap(data_yes2.corr(),annot=True).set_ylim(8,0)
plt.title('emg-1569406226_1')
# Out:
# Correlation of EMG sensors for "YES" gesture
# Text(0.5, 1, 'emg-1569406226_1')
